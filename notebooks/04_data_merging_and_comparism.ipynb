# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
diabetes_data = pd.read_csv("../data/processed/diabetes_data_processed.csv")
heart_data = pd.read_csv("../data/processed/heart_data_processed.csv")

# %% [markdown]
# # Decision on Dataset Merging
#
# The two datasets, `diabetes_processed` and `heart_disease_processed`, come from different parts of the world and do not share a reliable merging key. The only potential key, `age`, is not unique and would lead to incorrect or ambiguous relationships if used for merging.
