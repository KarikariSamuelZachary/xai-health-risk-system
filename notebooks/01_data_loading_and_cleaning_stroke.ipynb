# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
stroke_dataset = pd.read_csv('data/raw/stroke.csv')

# %%
print(stroke_dataset.columns)
# Out:
# Index(['id', 'gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status', 'stroke'],
#       dtype='object')

# %%
stroke_table = {
    "Name": ['id', 'gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
       'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
       'smoking_status', 'stroke'],
    "Unit": ['no unit', 'category', 'years', 'binary', 'category', 'category', 'category', 'mg/dL',
             'kg/m²', 'category', 'binary']
             }
